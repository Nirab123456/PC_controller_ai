# %%
from Data_collection_pandas import pandas_data_collection
import pandas as pd
import time

# %%
# pdc = pandas_data_collection()

# x=pdc.base_df()
# selected_columns = ['Name', 'cpu_uses', 'memory_uses','Wi_fi_uses','disc_uses','Type']

# # Create a new DataFrame with the selected columns
# new_df = x[selected_columns].copy()

# # Shuffle the rows
# new_df = new_df.sample(frac=1).reset_index(drop=True)

# # Reset the index
# new_df = new_df.reset_index()
# new_df = new_df.dropna()

# %%
pdc = pandas_data_collection()

# %%
x= pdc.base_intarected_df()

# %%
x
# Out:
#        Name  cpu_uses  memory_uses  Wi_fi_uses  disc_uses  Column_5  Column_6  \
# 0  Code.exe      28.8    85.789409         0.0        0.0       NaN       NaN
# 1      Disk       0.0     0.000000         0.0        0.0       NaN       NaN
#
#    Column_7  Column_8  Column_9  ...  Column_22  Column_23  Column_24  \
# 0       NaN       NaN       NaN  ...        NaN        NaN        NaN
# 1       NaN       NaN       NaN  ...        NaN        NaN        NaN
#
#    Column_25  Column_26  Column_27  Column_28  Column_29  Column_30  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
#
#                         Type
# 0  non_interacting_processes
# 1  non_interacting_processes
#
# [2 rows x 32 columns]

# %%
# Instantiate the pandas_data_collection class
pdc = pandas_data_collection()

inner_dfs = []  # Create an empty list to store the dataframes for each inner loop
outer_dfs = []  # Create an empty list to store the merged dataframes for each outer loop

for outer_loop in range(10000):
    for inner_loop in range(1):
        df = pdc.base_df()
        selected_columns = ['Name', 'cpu_uses', 'memory_uses','Wi_fi_uses','disc_uses','Type']

        # Create a new DataFrame with the selected columns
        new_df = df[selected_columns].copy()

        # Shuffle the rows
        new_df = new_df.sample(frac=1).reset_index(drop=True)

        # Reset the index
        new_df = new_df.reset_index()
        new_df = new_df.dropna()
        df = new_df
        inner_dfs.append(df)

    # Concatenate the dataframes from the inner loop
    merged_df = pd.concat(inner_dfs, ignore_index=True)
    outer_dfs.append(merged_df)

    inner_dfs = []  # Clear the list of inner dataframes

# Merge the dataframes from the outer loop
result_df = pd.concat(outer_dfs, ignore_index=True)

# %%
result_df = result_df.reset_index(drop=True)
result_df = result_df.drop('index', axis=1)

# %%
result_df = result_df.reset_index(drop=True)

# %%
result_df = result_df.drop('index', axis=1)

# %%
result_df
# Out:
#                    Name  cpu_uses  memory_uses  Wi_fi_uses  disc_uses  \
# 0                  Disk       0.0     0.000000         0.0        0.0
# 1              Registry       0.0     0.159526         0.0        0.0
# 2              Code.exe       0.0    50.116284         0.0        0.0
# 3           wininit.exe       0.0     0.026884         0.0        0.0
# 4             obs64.exe       0.0     3.058124         0.0        0.0
# 5                System       0.0     0.037485         0.0        0.0
# 6              smss.exe       0.0     0.004459         0.0        0.0
# 7        powershell.exe       0.0     1.209063         0.0        0.0
# 8                  Disk       0.0     0.000000         0.0        0.0
# 9        SearchHost.exe       0.0     1.365453         0.0        0.0
# 10          MsMpEng.exe       0.0     1.037973         0.0        0.0
# 11          PSAgent.exe       0.0     0.007807         0.0        0.0
# 12          svchost.exe       0.0     4.737468         0.0        0.0
# 13  System Idle Process    1534.7     0.000033         0.0        0.0
# 14           chrome.exe       0.0     3.803129         0.0        0.0
# 15           msedge.exe       0.0    12.572227         0.0        0.0
# 16                            0.0     0.238464         0.0        0.0
# 17            csrss.exe       0.0     0.066721         0.0        0.0
# 18         explorer.exe       0.0     1.043167         0.0        0.0
# 19                            0.0     0.238464         0.0        0.0
# 20                 Disk       0.0     0.000000         0.0        0.0
# 21            obs64.exe       0.0     3.056556         0.0        0.0
# 22           chrome.exe       0.0     3.808780         0.0        0.0
# 23               System       5.6     0.037485         0.0        0.0
# 24          PSAgent.exe       0.0     0.007807         0.0        0.0
# 25       powershell.exe       0.0     1.209095         0.0        0.0
# 26             Registry       0.0     0.159640         0.0        0.0
# 27             smss.exe       0.0     0.004459         0.0        0.0
# 28  System Idle Process    1506.7     0.000033         0.0        0.0
# 29          MsMpEng.exe       0.0     1.009275         0.0        0.0
# 30             Code.exe       2.7    50.040090         0.0        0.0
# 31          wininit.exe       0.0     0.026884         0.0        0.0
# 32                 Disk       0.0     0.000000         0.0        0.0
# 33       SearchHost.exe       0.0     1.365453         0.0        0.0
# 34         explorer.exe       0.0     1.008573         0.0        0.0
# 35           msedge.exe       0.0    12.409925         0.0        0.0
# 36            csrss.exe       0.0     0.066819         0.0        0.0
# 37          svchost.exe       0.0     4.766639         0.0        0.0
# 38            obs64.exe       0.0     3.061342         0.0        0.0
# 39       powershell.exe       0.0     1.209112         0.0        0.0
# 40  System Idle Process    1530.1     0.000033         0.0        0.0
# 41             smss.exe       0.0     0.004459         0.0        0.0
# 42             Registry       0.0     0.159640         0.0        0.0
# 43          PSAgent.exe       0.0     0.007807         0.0        0.0
# 44          svchost.exe       0.0     4.764352         0.0        0.0
# 45           msedge.exe       0.0    12.355944         0.0        0.0
# 46             Code.exe       9.0    50.220065         0.0        0.0
# 47         explorer.exe       0.0     1.006433         0.0        0.0
# 48               System       0.0     0.037485         0.0        0.0
# 49          wininit.exe       0.0     0.026884         0.0        0.0
# 50            csrss.exe       0.0     0.066803         0.0        0.0
# 51                 Disk       0.0     0.000000         0.0        0.0
# 52           chrome.exe       0.0     4.063170         0.0        0.0
# 53                 Disk       0.0     0.000000         0.0        0.0
# 54       SearchHost.exe       0.0     1.365453         0.0        0.0
# 55          MsMpEng.exe       0.0     1.004767         0.0        0.0
# 56                            0.0     0.238464         0.0        0.0
#
#                          Type
# 0       interacting_processes
# 1   non_interacting_processes
# 2       interacting_processes
# 3   non_interacting_processes
# 4   non_interacting_processes
# 5   non_interacting_processes
# 6   non_interacting_processes
# 7   non_interacting_processes
# 8   non_interacting_processes
# 9   non_interacting_processes
# 10  non_interacting_processes
# 11  non_interacting_processes
# 12  non_interacting_processes
# 13  non_interacting_processes
# 14  non_interacting_processes
# 15  non_interacting_processes
# 16  non_interacting_processes
# 17  non_interacting_processes
# 18  non_interacting_processes
# 19  non_interacting_processes
# 20  non_interacting_processes
# 21  non_interacting_processes
# 22  non_interacting_processes
# 23  non_interacting_processes
# 24  non_interacting_processes
# 25  non_interacting_processes
# 26  non_interacting_processes
# 27  non_interacting_processes
# 28  non_interacting_processes
# 29  non_interacting_processes
# 30      interacting_processes
# 31  non_interacting_processes
# 32      interacting_processes
# 33  non_interacting_processes
# 34  non_interacting_processes
# 35  non_interacting_processes
# 36  non_interacting_processes
# 37  non_interacting_processes
# 38  non_interacting_processes
# 39  non_interacting_processes
# 40  non_interacting_processes
# 41  non_interacting_processes
# 42  non_interacting_processes
# 43  non_interacting_processes
# 44  non_interacting_processes
# 45  non_interacting_processes
# 46      interacting_processes
# 47  non_interacting_processes
# 48  non_interacting_processes
# 49  non_interacting_processes
# 50  non_interacting_processes
# 51      interacting_processes
# 52  non_interacting_processes
# 53  non_interacting_processes
# 54  non_interacting_processes
# 55  non_interacting_processes
# 56  non_interacting_processes

# %%
result_df.to_csv('your_personal_df.csv', index=False)

# %%
result_df.to_csv('result1_df.csv', index=False)
